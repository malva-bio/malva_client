# %%
API_TOKEN = "" # place your token here

# %%
import dnaio
from malva_client import MalvaClient
from malva_client.tools import mask_sequence
import matplotlib.pyplot as plt

client = MalvaClient("https://malva.mdc-berlin.de", API_TOKEN)
# Out:
# INFO:malva_client.client:Connected to Malva API: healthy
# INFO:malva_client.client:Authenticated successfully: free account

# %%
sequences = {}
sequences_id = ['covid', 'hepC', 'hiv1', 'humanRV', 'measles', 'phix', 'westnile', 'zika']

for sid in sequences_id:
    with dnaio.open(f"sequences/{sid}.fa") as f_in:
        for s in f_in:
            sequences[sid] = s.sequence
            break

# %%
results = {}

for sid, seq in sequences.items():
    seq = mask_sequence(seq)
    results[sid] = client.search(seq)
# Out:
# INFO:malva_client.client:Search completed with job ID: fbe606dc-0b65-4115-aedf-210dc14bc2b1
# INFO:malva_client.client:Search completed with job ID: f7010064-bf16-4e12-b296-744ffdc9db40
# INFO:malva_client.client:Search completed with job ID: 81d3f935-4f2a-4021-a9f7-188a3e5e38bb
# INFO:malva_client.client:Search completed with job ID: ace51366-837e-4938-8b95-fc31c75ec749
# INFO:malva_client.client:Search completed with job ID: 29ce5cde-7b12-4bfd-bf63-5edf8ff7c6db
# INFO:malva_client.client:Search completed with job ID: c70fa182-7850-41a8-b282-d2d18822d967
# INFO:malva_client.client:Search completed with job ID: 99ef5042-6edc-4e25-a6cd-490f287659b1
# INFO:malva_client.client:Search completed with job ID: d5e3ce7d-c4fb-4e64-9075-8ca409a0c0a5

# %%
for rid, result in results.items():
    result.enrich_with_metadata()
# Out:
# ✓ Enriched with metadata for 2 samples
# ✓ Enriched with metadata for 25 samples
# ✓ Enriched with metadata for 4235 samples
# ✓ Enriched with metadata for 1000 samples

# %%
fig = results['humanRV'].plot_expression_summary("organ")
# Out:
# /local/malva/envs/dleonpe/miniforge3/envs/malva/lib/python3.11/site-packages/malva_client/models.py:358: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   top_categories = (self._df.groupby(group_by)['norm_expr']
# /local/malva/envs/dleonpe/miniforge3/envs/malva/lib/python3.11/site-packages/malva_client/models.py:394: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   sample_counts = plot_data.groupby(group_by)['sample_id'].nunique().reindex(top_categories)
# ...

# %%
fig = results['hiv1'].plot_expression_summary("organ")
# Out:
# /local/malva/envs/dleonpe/miniforge3/envs/malva/lib/python3.11/site-packages/malva_client/models.py:358: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   top_categories = (self._df.groupby(group_by)['norm_expr']
# /local/malva/envs/dleonpe/miniforge3/envs/malva/lib/python3.11/site-packages/malva_client/models.py:394: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   sample_counts = plot_data.groupby(group_by)['sample_id'].nunique().reindex(top_categories)
# ...

# %%
fig = results['phix'].plot_expression_summary("organ")
# Out:
# /local/malva/envs/dleonpe/miniforge3/envs/malva/lib/python3.11/site-packages/malva_client/models.py:358: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   top_categories = (self._df.groupby(group_by)['norm_expr']
# /local/malva/envs/dleonpe/miniforge3/envs/malva/lib/python3.11/site-packages/malva_client/models.py:394: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   sample_counts = plot_data.groupby(group_by)['sample_id'].nunique().reindex(top_categories)
# ...
