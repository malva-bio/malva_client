# %% [markdown]
# # Setting up the Malva Client

# %% [markdown]
# **Two Modes of Malva Access**
#
# Malva provides two complementary interfaces for different use cases:
#
# 1. Web Interface: User-friendly browser-based access at https://malva.mdc-berlin.de for interactive exploration and visualization
# 2. API/Command Line: Programmatic access for automated analyses, batch processing, and integration into computational workflows
#
# This notebook focuses on the programmatic interface, which enables integration with existing analysis pipelines and batch querying
#
# The Malva platform is currently in beta phase, running on our core infrastructure. For data protection and resource management:
#
# - Users receive 20 queries per day (extensible upon request)
# - Production deployment with expanded access is planned

# %% [markdown]
# ## 0. Installing the Malva python package

# %%
# run from a terminal, make sure you're in the root of the malva_api folder
# pip install .

# %% [markdown]
# ## 1. Login and API setup

# %% [markdown]
# **Generating your API token**
#
# To access Malva programmatically:
#
# - **A**:. If you got a token from us, paste it below
# - **B**: If you prefer to login with your ORCID account, follow these steps
#     1. Navigate to [https://malva.mdc-berlin.de](https://malva.mdc-berlin.de), and login with your ORCID
#     2. Click the menu button (⋯) in the upper left corner
#     3. Select "Profile" from the dropdown
#     4. Click "Generate API Token"
#     5. Copy the generated token and paste it below
#
# This token provides secure, authenticated access to the Malva API while maintaining usage tracking and access controls.

# %%
API_TOKEN = "" # place your token here
# !malva_client config --server https://malva.mdc-berlin.de --token {API_TOKEN}
# Out:
# Set server_url to: https://malva.mdc-berlin.net
# Set api_token: ***
# Configuration saved to: /home/dleonpe/.malva/config.json
